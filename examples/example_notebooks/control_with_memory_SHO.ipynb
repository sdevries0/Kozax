# %% [markdown]
# # Memory-based control policy optimization (Stochastic Harmonic Oscillator)
#
# In this more advanced example, we will optimize a symbolic control policy that is extended with a dynamic latent memory (check out this paper for more details: https://arxiv.org/abs/2406.02765). The memory is defined by a set of differential equations, consisting of a tree for each latent unit. The memory updates every time step, and the control policy maps the memory to a control signal via an additional readout tree. This setup is applied to stabilization of the stochastic harmonic oscillator at random targets.

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
from kozax.environments.control_environments.harmonic_oscillator import HarmonicOscillator
# Out:
# These device(s) are detected: [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    noise_keys = jr.split(noise_key, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    return x0, ts, targets, noise_keys, params

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 8
T = 40
dt = 0.2
param_setting = "Constant"

env = HarmonicOscillator(process_noise = 0.05, obs_noise = 0.05)

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment, defined by the drift and diffusion functions. At every time step, the state of the environment is mapped to observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
class Evaluator:
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        process_noise_key, obs_noise_key = jr.split(noise_key, 2)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([x0, jnp.zeros(self.state_size)])

        brownian_motion = diffrax.UnsafeBrownianPath(shape=(env.n_var,), key=process_noise_key, levy_area=diffrax.SpaceTimeLevyArea) #define process noise
        system = diffrax.MultiTerm(diffrax.ODETerm(self._drift), diffrax.ControlTerm(self._diffusion, brownian_motion))
        
        # Solve the coupled system of the environment and the controller
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, _x0, saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([dx, da])
    
    def _diffusion(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        return jnp.concatenate([env.diffusion(t, x, jnp.array([0])), jnp.zeros((self.state_size, self.latent_size))]) #Only the system is stochastic

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 50
state_size = 2

#Define expressions
operator_list = [("+", lambda x, y: x + y, 2, 0.5), 
                ("-", lambda x, y: x - y, 2, 0.1),
                ("*", lambda x, y: x * y, 2, 0.5)]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a0", "a1", "u", "tar"], ["a0", "a1", "tar"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

#Define evaluator
fitness_function = Evaluator(env, state_size, 0.05, solver=diffrax.GeneralShARK(), max_steps=1000)

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations)

strategy.fit(gp_key, data, verbose=True)
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a0', 'a1', 'u', 'tar'].
# Compiling code for evaluation and evolution...
# Finished compilation in 12.47 seconds
# In generation 1
# Complexity: 11, fitness: 17.793970108032227, equations: [2*u + x0, a1*x0, -1.42*tar]
# Complexity: 13, fitness: 3.983767509460449, equations: [a1*tar, u**2, a0 + a1**2 + a1]
# Complexity: 15, fitness: 2.507082939147949, equations: [tar + u, -0.0217*a0 - 0.0217*x0 - 0.0217*x1, tar]
# Complexity: 19, fitness: 2.29964017868042, equations: [u - x0, a1*(a0*x1 + a1), 2*a0*a1 + 0.572*tar]
# In generation 2
# Complexity: 9, fitness: 3.983767509460449, equations: [-2.36*u, a1, a1*(a1 + tar)]
# Complexity: 15, fitness: 2.507082939147949, equations: [tar + u, -0.0217*a0 - 0.0217*x0 - 0.0217*x1, tar]
# Complexity: 19, fitness: 2.29964017868042, equations: [u - x0, a1*(a0*x1 + a1), 2*a0*a1 + 0.572*tar]
# Complexity: 31, fitness: 2.229334592819214, equations: [a1*(a0 - (a0 - 0.47)*(u + x1)), a0*u**2*x1, (0.575 - 2.04*a0)*(a1 + 1.26*tar)]
# In generation 3
# Complexity: 9, fitness: 3.983767509460449, equations: [-2.36*u, a1, a1*(a1 + tar)]
# Complexity: 11, fitness: 2.507082939147949, equations: [1.38*x1, a0**2*x1**2, tar]
# Complexity: 17, fitness: 2.29964017868042, equations: [x0*x1 - x0, a1**2, 2*a0*a1 + 0.572*tar]
# Complexity: 23, fitness: 2.2968225479125977, equations: [a0*a1**2, a0*u*x0*x1, tar*(0.575 - 2.04*a0)]
# Complexity: 31, fitness: 2.229334592819214, equations: [a1*(a0 - (a0 - 0.47)*(u + x1)), a0*u**2*x1, (0.575 - 2.04*a0)*(a1 + 1.26*tar)]
# In generation 4
# Complexity: 7, fitness: 2.507082939147949, equations: [x1 + 1.38, u*x1, tar]
# Complexity: 9, fitness: 2.4332189559936523, equations: [a1*u, x0 - 0.227, 0.471*tar]
# Complexity: 17, fitness: 2.29964017868042, equations: [u - x0, a1*(a0*x1 + u), 2*a1 + 0.572*tar]
# Complexity: 19, fitness: 2.2968225479125977, equations: [a1**2*tar, a1*x1, tar*(0.575 - 2.04*a0)]
# Complexity: 25, fitness: 2.229307174682617, equations: [a1*tar**2*u*x0, a0*a1*(a0 + x0)*(x0 - x1), a0 + 0.724*tar]
# In generation 5
# Complexity: 7, fitness: 2.507082939147949, equations: [x1 + 1.38, u*x1, tar]
# Complexity: 9, fitness: 2.4332189559936523, equations: [a1*u, x0 - 0.227, 0.471*tar]
# Complexity: 11, fitness: 2.29964017868042, equations: [a1, a1**2, a0*tar + 0.572*tar]
# Complexity: 17, fitness: 2.229156255722046, equations: [a0 + a1, -0.208*a0*u, 0.138*a1 + 0.71*tar]
# Complexity: 33, fitness: 2.229057788848877, equations: [a0*(a0 + a1)*(a0 + x1), a1*x1*(a0 + 0.709)*(a1 + x1), -0.285*a0*a1*(-a1 - 0.365) + 0.715*tar]
# In generation 6
# Complexity: 5, fitness: 6.404603958129883, equations: [x0, a1**2, -1.30]
# Complexity: 7, fitness: 2.507082939147949, equations: [x1 + 1.38, u*x1, tar]
# Complexity: 9, fitness: 2.4332189559936523, equations: [a1*u, x0 - 0.227, 0.471*tar]
# Complexity: 11, fitness: 2.29964017868042, equations: [a1, a1**2, a0*tar + 0.572*tar]
# Complexity: 17, fitness: 2.229156255722046, equations: [a0 + a1, -0.208*a0*u, 0.138*a1 + 0.71*tar]
# Complexity: 21, fitness: 2.222169876098633, equations: [a1 + tar - x0*x1 + x0, a1*tar*u, 0.0192*a0 + 0.572*tar]
# In generation 7
# Complexity: 5, fitness: 6.404603958129883, equations: [x0, a1**2, -1.30]
# Complexity: 7, fitness: 2.507082939147949, equations: [x0, a1*u, a1 + tar]
# Complexity: 9, fitness: 2.29964017868042, equations: [x1, 2*a1*u, 0.572*tar]
# Complexity: 15, fitness: 1.8849642276763916, equations: [tar, u*x1, 0.0192*a0 + 0.572*tar]
# In generation 8
# Complexity: 5, fitness: 6.404603958129883, equations: [x0, a1**2, -1.30]
# Complexity: 7, fitness: 2.29964017868042, equations: [x0, a1*x1, 0.572*tar]
# Complexity: 13, fitness: 2.2965445518493652, equations: [u - 2*x0, u**2, 0.572*tar - 0.196]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u*x0, 0.0192*a0 + 0.572*tar]
# In generation 9
# Complexity: 5, fitness: 2.507082939147949, equations: [a0, u**2, tar]
# Complexity: 7, fitness: 2.29964017868042, equations: [x0, a1*x1, 0.572*tar]
# Complexity: 11, fitness: 2.2751879692077637, equations: [x1, a1**2, -0.0216*a0 + 0.572*tar]
# Complexity: 13, fitness: 2.229156255722046, equations: [a0*a1, 2*a1*tar*u, 0.71*tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u*x0, 0.0192*a0 + 0.572*tar]
# Complexity: 35, fitness: 0.9393899440765381, equations: [(-a0 + x1)*(2*a0 + x1), a1**2*u*x1**2*(a0 + 0.709), -0.285*a0 - 0.285*a1**2 - 0.285*a1 + 0.715*tar]
# In generation 10
# Complexity: 5, fitness: 2.507082939147949, equations: [a0, a1*x0, tar]
# Complexity: 7, fitness: 2.29964017868042, equations: [x0, a1*x1, 0.572*tar]
# Complexity: 9, fitness: 2.201118230819702, equations: [a0 + a1, tar, 0.71*tar - 0.194]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 33, fitness: 0.6814931035041809, equations: [(-a0 + x1)*(2*a0 + x1), a1*x1*(a0 + 0.709)*(a1 + u*x1), -0.57*a0 - 0.285*a1 + 0.715*tar]
# In generation 11
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 25, fitness: 0.592230498790741, equations: [-a0 + x1, a1**2*u*x1**2, -0.285*a0 - 0.285*a1**2 - 0.285*a1 + 0.715*tar]
# In generation 12
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 13, fitness: 2.199718713760376, equations: [a0 + x1, -1.36*a1, a1 + 0.71*tar - 0.138]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 23, fitness: 0.592230498790741, equations: [-a0 + x1, a1**2*x1**2, -0.285*a0 - 0.285*a1**2 - 0.285*a1 + 0.715*tar]
# In generation 13
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 13, fitness: 2.199718713760376, equations: [a0 + x1, -1.36*a1, a1 + 0.71*tar - 0.138]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# In generation 14
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# In generation 15
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 37, fitness: 0.3237273693084717, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a1 + 1.03), -0.285*a0 - 0.285*a1 + 1.43*tar]
# In generation 16
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 37, fitness: 0.3237273693084717, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a1 + 1.03), -0.285*a0 - 0.285*a1 + 1.43*tar]
# In generation 17
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 29, fitness: 0.45129042863845825, equations: [-a0 + x1 + 0.11, a1**2*x0*(a1 + 1.06)*(x0*x1 + 1.03), -0.285*a0 - 0.285*a1 + tar - 0.133]
# Complexity: 31, fitness: 0.37812238931655884, equations: [-a0 + u + 2*x1, a1**2*tar*u*x1**2, 0.285*a0*a1 - 0.285*a0 + tar]
# Complexity: 37, fitness: 0.3237273693084717, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a1 + 1.03), -0.285*a0 - 0.285*a1 + 1.43*tar]
# In generation 18
# Complexity: 3, fitness: 4.2769317626953125, equations: [tar, a1, -0.392]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 29, fitness: 0.45129042863845825, equations: [-a0 + x1 + 0.11, a1**2*x0*(a1 + 1.06)*(x0*x1 + 1.03), -0.285*a0 - 0.285*a1 + tar - 0.133]
# Complexity: 31, fitness: 0.37812238931655884, equations: [-a0 + u + 2*x1, a1**2*tar*u*x1**2, 0.285*a0*a1 - 0.285*a0 + tar]
# Complexity: 37, fitness: 0.3237273693084717, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a1 + 1.03), -0.285*a0 - 0.285*a1 + 1.43*tar]
# In generation 19
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 29, fitness: 0.45129042863845825, equations: [-a0 + x1 + 0.11, a1**2*x0*(a1 + 1.06)*(x0*x1 + 1.03), -0.285*a0 - 0.285*a1 + tar - 0.133]
# Complexity: 31, fitness: 0.37812238931655884, equations: [-a0 + u + 2*x1, a1**2*tar*u*x1**2, 0.285*a0*a1 - 0.285*a0 + tar]
# Complexity: 37, fitness: 0.3237273693084717, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a1 + 1.03), -0.285*a0 - 0.285*a1 + 1.43*tar]
# In generation 20
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 27, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a1**2*tar*(u + x1), -0.285*a0 + 0.285*a1 + 1.29*tar - 0.0414]
# In generation 21
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 27, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a1**2*tar*(u + x1), -0.285*a0 + 0.285*a1 + 1.29*tar - 0.0414]
# In generation 22
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 27, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a1**2*tar*(u + x1), -0.285*a0 + 0.285*a1 + 1.29*tar - 0.0414]
# Complexity: 39, fitness: 0.22895458340644836, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a0 + 1.03), -0.57*a0 + 0.715*a1 + 1.71*tar]
# In generation 23
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 15, fitness: 1.8849639892578125, equations: [tar, u + x0, 0.0192*a0 + 0.572*tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 27, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a1**2*tar*(u + x1), -0.285*a0 + 0.285*a1 + 1.29*tar - 0.0414]
# Complexity: 39, fitness: 0.22895458340644836, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a0 + 1.03), -0.57*a0 + 0.715*a1 + 1.71*tar]
# In generation 24
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 27, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a1**2*tar*(u + x1), -0.285*a0 + 0.285*a1 + 1.29*tar - 0.0414]
# Complexity: 35, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1**6*tar**2, -0.285*a0 + 0.285*a1*(a1 - 0.145) + tar]
# Complexity: 39, fitness: 0.22895458340644836, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a0 + 1.03), -0.57*a0 + 0.715*a1 + 1.71*tar]
# In generation 25
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 25, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a0*a1*x1, -0.285*a0 + 1.29*a1 + 1.29*tar - 0.0414]
# Complexity: 35, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1**7*tar, -0.285*a0 + 0.285*a1*(a1 - 0.145) + tar]
# Complexity: 39, fitness: 0.22895458340644836, equations: [-a0 + a1 + u + 2*x1, a1**4*x1**2*(a0 + 1.03), -0.57*a0 + 0.715*a1 + 1.71*tar]
# In generation 26
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 19, fitness: 1.1236090660095215, equations: [-a0 + x1, -1.04*a0 - 0.739, -0.57*a0 + 0.43*tar]
# Complexity: 21, fitness: 0.46429216861724854, equations: [-a0 + x1, -1.04*a1*u*x1, -0.57*a0 - 0.285*a1 + 0.715*tar]
# Complexity: 25, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a0*a1*x1, -0.285*a0 + 1.29*a1 + 1.29*tar - 0.0414]
# Complexity: 27, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1**3*tar, -0.285*a0 + 0.0414*a1**2 + tar]
# Complexity: 29, fitness: 0.22363819181919098, equations: [-a0 + tar + 3*x1, a0*a1*x1, -0.285*a0 + 2.29*a1 + 1.29*tar - 0.0414]
# In generation 27
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.32161861658096313, equations: [-a0 + 2*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 25, fitness: 0.27109968662261963, equations: [-a0 + u + 2*x1, a0*a1*x1, -0.285*a0 + 1.29*a1 + 1.29*tar - 0.0414]
# Complexity: 27, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1**3*tar, -0.285*a0 + 0.0414*a1**2 + tar]
# Complexity: 29, fitness: 0.22363819181919098, equations: [-a0 + tar + 3*x1, a0*a1*x1, -0.285*a0 + 2.29*a1 + 1.29*tar - 0.0414]
# Complexity: 31, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a0**2*a1**2 + a1, -0.285*a0 + 0.285*a1*(a1 - 0.145) + tar]
# In generation 28
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.32161861658096313, equations: [-a0 + 2*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 17, fitness: 0.2731029987335205, equations: [-a0 + 3*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 25, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1**3, -0.285*a0 + 0.285*a1*(a1 - tar) + tar]
# Complexity: 29, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1**6*tar, -0.285*a0 + tar]
# Complexity: 35, fitness: 0.21518650650978088, equations: [-1.46*a0 + 2.92*x1, a1**6*tar, -0.285*a0 + 0.285*a1*(a1 - 0.145) + tar]
# In generation 29
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.32161861658096313, equations: [-a0 + 2*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 17, fitness: 0.2731029987335205, equations: [-a0 + 3*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 19, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, -1.02*a1, -0.285*a0 + 0.285*a1 + tar]
# Complexity: 27, fitness: 0.22929956018924713, equations: [-a0 + 0.639*a1*tar + x1, a1**4*u*x1, -1.51*a0 + tar]
# Complexity: 29, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1**6*tar, -0.285*a0 + tar]
# Complexity: 31, fitness: 0.2161422073841095, equations: [-a0 + tar + 4*x1, a0*a1*x1, -0.285*a0 + 2.29*a1 + 1.29*tar - 0.0414]
# Complexity: 35, fitness: 0.21518650650978088, equations: [-1.46*a0 + 2.92*x1, a1**7, -0.285*a0 + 0.285*a1*(a1 - 0.145) + tar]
# Complexity: 39, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1**4, -0.285*a0 + 0.285*a1*(a1 - tar) + tar]
# In generation 30
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.32161861658096313, equations: [-a0 + 2*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 17, fitness: 0.2731029987335205, equations: [-a0 + 3*x1, tar*x0, -0.285*a0 + tar + 0.246]
# Complexity: 19, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, -1.02*a1, -0.285*a0 + 0.285*a1 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 35, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0**2*a1**2*x1, -0.285*a0 + 0.285*a1 + tar]
# In generation 31
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 31, fitness: 0.20102903246879578, equations: [-2*a0 + a1 + 4*x1, a0*a1, -0.285*a0 + 0.202*a1*tar + tar]
# Complexity: 33, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a0**2*a1**2*x1, -0.285*a0 + 0.285*a1 + tar]
# Complexity: 35, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0**2*a1**2*x1, -0.285*a0 + 0.285*a1 + tar]
# In generation 32
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.1936386525630951, equations: [-1.46*a0 + 1.46*u + 4.38*x1, a1**3*tar**2, -0.285*a0 - 0.285*a1 + 1.29*tar]
# Complexity: 31, fitness: 0.19053241610527039, equations: [-2*a0 + 5*x1, a1**3*x1, -0.285*a0 + 0.285*a1 + tar]
# Complexity: 35, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0**2*a1, -0.285*a0 + 0.285*a1*(a1 - tar) + tar]
# In generation 33
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.19053241610527039, equations: [-2*a0 + a1 + 5*x1, a1**3, -0.285*a0 + tar]
# Complexity: 35, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0**2*a1, -0.285*a0 + 0.285*a1*(a1 - tar) + tar]
# In generation 34
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.19053241610527039, equations: [-2*a0 + a1 + 5*x1, a1**3, -0.285*a0 + tar]
# Complexity: 31, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a1, -0.285*a0 + 0.285*a1*(a1 - tar) + tar]
# In generation 35
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1**2, -0.285*a0 + tar]
# In generation 36
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1**2, -0.285*a0 + tar]
# In generation 37
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 29, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1**2, -0.285*a0 + tar]
# In generation 38
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 27, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1, -0.285*a0 + tar]
# In generation 39
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 25, fitness: 0.21301594376564026, equations: [-a0 + a1 + 4*x1, a1**2*x1, -0.285*a0 + 2*a1 + tar]
# Complexity: 27, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, a0*a1, -0.285*a0 + tar]
# In generation 40
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# In generation 41
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# In generation 42
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# In generation 43
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# In generation 44
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18892869353294373, equations: [-2*a0 + 6*x1, 2*a1, -0.265*a0 + 0.485*a1 + tar]
# Complexity: 35, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a0*a1**2*x0, -0.57*a0 + 0.285*a1*tar*(tar - 0.145) + tar]
# In generation 45
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18892869353294373, equations: [-2*a0 + 6*x1, 2*a1, -0.265*a0 + 0.485*a1 + tar]
# Complexity: 35, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a0*a1**2*x0, -0.57*a0 + 0.285*a1*tar*(tar - 0.145) + tar]
# In generation 46
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18892869353294373, equations: [-2*a0 + 6*x1, 2*a1, -0.265*a0 + 0.485*a1 + tar]
# Complexity: 35, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, 0.0595*a0*a1*x0, -0.57*a0 - 0.285*a1*tar*(tar - 0.145) + tar]
# In generation 47
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18892869353294373, equations: [-2*a0 + 6*x1, 2*a1, -0.265*a0 + 0.485*a1 + tar]
# Complexity: 35, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a1**4, -0.57*a0 + 0.285*a1*tar*(-a0 + tar) + tar]
# In generation 48
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18892869353294373, equations: [-2*a0 + 6*x1, 2*a1, -0.265*a0 + 0.485*a1 + tar]
# Complexity: 35, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a1**4, -0.57*a0 + 0.285*a1*tar*(-a0 + tar) + tar]
# In generation 49
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a1**2*x0**2, -0.57*a0 + tar]
# In generation 50
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a1**2*x0**2, -0.57*a0 + tar]
# Final pareto front:
# Complexity: 3, fitness: 2.507082939147949, equations: [a1, -1.04, tar]
# Complexity: 5, fitness: 2.4274516105651855, equations: [a0, a1, tar - 0.194]
# Complexity: 7, fitness: 2.201118230819702, equations: [x1, a1, 0.71*tar - 0.194]
# Complexity: 9, fitness: 2.1994733810424805, equations: [u, a1, a1 + 0.71*tar - 0.145]
# Complexity: 11, fitness: 2.100986957550049, equations: [-a0 + x1, a1, -0.0216*a0*tar + tar]
# Complexity: 13, fitness: 1.2932003736495972, equations: [-a0 + x1 - 3.18, a1*x1, -0.285*a0 + tar]
# Complexity: 15, fitness: 0.2570898234844208, equations: [-a0 + 2*x1, a1, -0.285*a0 + tar]
# Complexity: 17, fitness: 0.21671634912490845, equations: [-a0 + 3*x1, a1, -0.285*a0 + tar]
# Complexity: 21, fitness: 0.19053243100643158, equations: [-2*a0 + 5*x1, a1**2, -0.285*a0 + tar]
# Complexity: 23, fitness: 0.18912631273269653, equations: [-2*a0 + 6*x1, u - 0.587, -0.285*a0 + tar]
# Complexity: 27, fitness: 0.18715113401412964, equations: [-3*a0 + 4*x1, a1**2*x0**2, -0.57*a0 + tar]

# %% [markdown]
# ## Visualize best solution

# %%
#Generate test_data
data = get_data(jr.PRNGKey(10), env, 4, 0.01, T, param_setting)
x0s, ts, targets, noise_key, params = data

best_candidate = strategy.pareto_front[1][jnp.argmin(strategy.pareto_front[0])]
print(strategy.expression_to_string(best_candidate))

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)

fig, ax = plt.subplots(2, 2, figsize=(10, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, xs[i,:,0], label="$x_0$", color = "blue")
    ax[i].plot(ts, xs[i,:,1], label="$x_1$", color = "orange")
    ax[i].plot(ts, ys[i,:,0], alpha=0.3, color = "blue")
    ax[i].plot(ts, ys[i,:,1], alpha=0.3, color = "orange")
    ax[i].plot(ts, us[i,:], label="$u$", color = "green")
    ax[i].hlines(targets[i], ts[0], ts[-1], linestyles='dashed', color = "black")

plt.suptitle("Trajectories of the stochastic harmonic oscillator controlled with a symbolic policy")
plt.legend(loc="best")
plt.show()
# Out:
# [-3*a0 + 4*x1, a1**2*x0**2, -0.57*a0 + tar]

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, activities[i,:,0], label="$a_0$", color = "red")
    ax[i].plot(ts, activities[i,:,1], label="$a_1$", color = "purple")

plt.suptitle("Latent activity of the memory of the policy")
plt.legend(loc="best")
plt.show()
