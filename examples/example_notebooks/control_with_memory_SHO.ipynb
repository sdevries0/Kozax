# %% [markdown]
# # Memory-based control policy optimization (Stochastic Harmonic Oscillator)
#
# In this more advanced example, we will optimize a symbolic control policy that is extended with a dynamic latent memory (check out this paper for more details: https://arxiv.org/abs/2406.02765). The memory is defined by a set of differential equations, consisting of a tree for each latent unit. The memory updates every time step, and the control policy maps the memory to a control signal via an additional readout tree. This setup is applied to stabilization of the stochastic harmonic oscillator at random targets.

# %%
# Specify the cores to use for XLA
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.numpy as jnp
import diffrax
import jax.random as jr
import matplotlib.pyplot as plt
from jax import Array
from typing import Tuple, Callable
import copy

from kozax.genetic_programming import GeneticProgramming
from kozax.environments.control_environments.harmonic_oscillator import HarmonicOscillator
# Out:
# These device(s) are detected: [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]

# %% [markdown]
# First we generate data, consisting of initial conditions, keys for noise, targets and parameters of the environment.

# %%
def get_data(key, env, batch_size, dt, T, param_setting):
    init_key, noise_key, param_key = jr.split(key, 3)
    x0, targets = env.sample_init_states(batch_size, init_key)
    noise_keys = jr.split(noise_key, batch_size)
    ts = jnp.arange(0, T, dt)

    params = env.sample_params(batch_size, param_setting, ts, param_key)
    return x0, ts, targets, noise_keys, params

key = jr.PRNGKey(0)
gp_key, data_key = jr.split(key)
batch_size = 8
T = 40
dt = 0.2
param_setting = "Constant"

env = HarmonicOscillator(process_noise = 0.05, obs_noise = 0.05)

data = get_data(data_key, env, batch_size, dt, T, param_setting)

# %% [markdown]
# The evaluator class parallelizes the simulation of the control loop over the batched data. In each trajectory, a coupled dynamical system is simulated using diffrax, integrating both the dynamic memory and the dynamic environment, defined by the drift and diffusion functions. At every time step, the state of the environment is mapped to observations and the latent memory is mapped to a control signal. Afterwards, the state equation of the memory and environment state is computed. When the simulation is done, the fitness is computed given the control and environment state.

# %%
from kozax.fitness_functions.base_fitness_function import BaseFitnessFunction
class Evaluator(BaseFitnessFunction):
    def __init__(self, env, state_size: int, dt0: float, solver=diffrax.Euler(), max_steps: int = 16**4, stepsize_controller: diffrax.AbstractStepSizeController = diffrax.ConstantStepSize()) -> None:
        """Evaluates dynamic symbolic policies in control tasks.

        Args:
            env: Environment on which the candidate is evaluated.
            state_size: Dimensionality of the hidden state.
            dt0: Initial step size for integration.
            solver: Solver used for integration (default: diffrax.Euler()).
            max_steps: The maximum number of steps that can be used in integration (default: 16**4).
            stepsize_controller: Controller for the stepsize during integration (default: diffrax.ConstantStepSize()).

        Attributes:
            env: Environment on which the candidate is evaluated.
            max_fitness: Max fitness which is assigned when a trajectory returns an invalid value.
            state_size: Dimensionality of the hidden state.
            obs_size: Dimensionality of the observations.
            control_size: Dimensionality of the control.
            latent_size: Dimensionality of the state of the environment.
            dt0: Initial step size for integration.
            solver: Solver used for integration.
            max_steps: The maximum number of steps that can be used in integration.
            stepsize_controller: Controller for the stepsize during integration.
        """
        super().__init__()
        self.env = env
        self.max_fitness = 1e4
        self.state_size = state_size
        self.obs_size = env.n_obs
        self.control_size = env.n_control_inputs
        self.latent_size = env.n_var*env.n_dim
        self.dt0 = dt0
        self.solver = solver
        self.max_steps = max_steps
        self.stepsize_controller = stepsize_controller

    def __call__(self, candidate: Array, data: Tuple, tree_evaluator: Callable) -> float:
        """Evaluates the candidate on a task.

        Args:
            candidate: The coefficients of the candidate.
            data: The data required to evaluate the candidate.
            tree_evaluator: Function for evaluating trees.

        Returns:
            Fitness of the candidate.
        """
        _, _, _, _, fitness = jax.vmap(self.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(candidate, *data, tree_evaluator)

        fitness = jnp.mean(fitness)
        return fitness
      
    def evaluate_trajectory(self, candidate: Array, x0: Array, ts: Array, target: float, noise_key: jr.PRNGKey, params: Tuple, tree_evaluator: Callable) -> Tuple[Array, Array, Array, Array, float]:
        """Solves the coupled differential equation of the system and controller. 
        The differential equation of the system is defined in the environment and the differential equation 
        of the control is defined by the set of trees.

        Args:
            candidate: Candidate with trees for the hidden state and readout.
            x0: Initial state of the system.
            ts: Time points on which the controller is evaluated.
            target: Target position that the system should reach.
            noise_key: Key to generate noisy observations.
            params: Parameters that define the environment.
            tree_evaluator: Function for evaluating trees.

        Returns:
            States, observations, control, activities of the hidden state of the candidate and the fitness of the candidate.
        """
        env = copy.copy(self.env)
        env.initialize_parameters(params, ts)

        state_equation = candidate[:self.state_size]
        readout = candidate[self.state_size:]
        
        solver = self.solver
        dt0 = self.dt0
        saveat = diffrax.SaveAt(ts=ts)

        process_noise_key, obs_noise_key = jr.split(noise_key, 2)

        # Concatenate the initial state of the system with the initial state of the latent memory
        _x0 = jnp.concatenate([x0, jnp.zeros(self.state_size)])

        brownian_motion = diffrax.UnsafeBrownianPath(shape=(env.n_var,), key=process_noise_key, levy_area=diffrax.SpaceTimeLevyArea) #define process noise
        system = diffrax.MultiTerm(diffrax.ODETerm(self._drift), diffrax.ControlTerm(self._diffusion, brownian_motion))
        
        # Solve the coupled system of the environment and the controller
        sol = diffrax.diffeqsolve(
            system, solver, ts[0], ts[-1], dt0, _x0, saveat=saveat, adjoint=diffrax.DirectAdjoint(), max_steps=self.max_steps, event=diffrax.Event(self.env.cond_fn_nan), 
            args=(env, state_equation, readout, obs_noise_key, target, tree_evaluator), stepsize_controller=self.stepsize_controller, throw=False
        )

        xs = sol.ys[:,:self.latent_size]
        # Get observations of the state at every time step
        _, ys = jax.lax.scan(env.f_obs, obs_noise_key, (ts, xs))

        activities = sol.ys[:,self.latent_size:]
        # Get control actions at every time step
        us = jax.vmap(lambda y, a, tar: tree_evaluator(readout, jnp.concatenate([y, a, jnp.zeros(self.control_size), target])), in_axes=[0,0,None])(ys, activities, target)

        # Compute the fitness of the candidate in this trajectory
        fitness = env.fitness_function(xs, us[:,None], target, ts)

        return xs, ys, us, activities, fitness
    
    def _drift(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        _, y = env.f_obs(obs_noise_key, (t, x)) #Get observations from system
        u = tree_evaluator(readout, jnp.concatenate([jnp.zeros(self.obs_size), a, jnp.zeros(self.control_size), target])) #Compute control action from latent memory

        u = jnp.atleast_1d(u)

        dx = env.drift(t, x, u) #Apply control to system and get system change
        da = tree_evaluator(state_equation, jnp.concatenate([y, a, u, target])) #Compute change in latent memory

        return jnp.concatenate([dx, da])
    
    def _diffusion(self, t, x_a, args):
        env, state_equation, readout, obs_noise_key, target, tree_evaluator = args
        x = x_a[:self.latent_size]
        a = x_a[self.latent_size:]

        return jnp.concatenate([env.diffusion(t, x, jnp.array([0])), jnp.zeros((self.state_size, self.latent_size))]) #Only the system is stochastic

# %% [markdown]
# Here we define the hyperparameters, operators, variables and initialize the strategy. The control policy will consist of two latent variables and a readout layer. `layer_sizes` allows us to define different types of tree, where `variable_list` contains different sets of input variables for each type of tree. The readout layer will only receive the latent states, while the inputs to the state equations consists of the observations, control signal and latent states.

# %%
#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 50
state_size = 2

#Define expressions
operator_list = [
    {"string": "+", "fn": lambda x, y: x + y, "arity": 2, "prob": 0.5, "flops": 1},
    {"string": "-", "fn": lambda x, y: x - y, "arity": 2, "prob": 0.1, "flops": 1},
    {"string": "*", "fn": lambda x, y: x * y, "arity": 2, "prob": 0.5, "flops": 1}
]

variable_list = [["x" + str(i) for i in range(env.n_obs)] + ["a0", "a1", "u", "tar"], ["a0", "a1", "tar"]]

layer_sizes = jnp.array([state_size, env.n_control_inputs])

#Define evaluator
fitness_function = Evaluator(env, state_size, 0.05, solver=diffrax.GeneralShARK(), max_steps=1000)

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, layer_sizes, num_populations = num_populations)

strategy.fit(gp_key, data, verbose=True)
# Out:
# Input data should be formatted as: ['x0', 'x1', 'a0', 'a1', 'u', 'tar'].
# Compiling code for evaluation and evolution...
# Finished compilation in 30.82 seconds
# In generation 1
# Complexity: 4.0, fitness: 17.793970108032227, equations: [2*u + x0, a1*x0, -1.42*tar]
# Complexity: 5.0, fitness: 3.98376727104187, equations: [a1*tar, u**2, a0 + a1**2 + a1]
# Complexity: 6.0, fitness: 2.507082939147949, equations: [tar + u, -0.0217*a0 - 0.0217*x0 - 0.0217*x1, tar]
# Complexity: 8.0, fitness: 2.29964017868042, equations: [u - x0, a1*(a0*x1 + a1), 2*a0*a1 + 0.572*tar]
# In generation 2
# Complexity: 1.0, fitness: 3974.090087890625, equations: [x1, -1.6*tar, a1]
# Complexity: 2.0, fitness: 11.022931098937988, equations: [a0*x1, x0*x1, -2.29]
# Complexity: 3.0, fitness: 3.98376727104187, equations: [tar, a0**2*a1*tar, a1]
# Complexity: 4.0, fitness: 2.507082939147949, equations: [u + 0.0213, 1.55*a0*a1*u, tar]
# Complexity: 8.0, fitness: 2.29964017868042, equations: [u - x0, a1*(a0*x1 + a1), 2*a0*a1 + 0.572*tar]
# Complexity: 13.0, fitness: 0.3098561763763428, equations: [-a1 - 0.121*tar - 1.12*u + 2.38, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 3
# Complexity: 1.0, fitness: 3974.090087890625, equations: [a0, -1.6*tar, a1]
# Complexity: 2.0, fitness: 3.98376727104187, equations: [x0, a1*(-tar - 0.904), a1]
# Complexity: 4.0, fitness: 2.507082939147949, equations: [u + 0.0213, 1.55*a0*a1*u, tar]
# Complexity: 6.0, fitness: 2.4264509677886963, equations: [a0*x1, 2*a0*a1, a1 + tar - 0.328]
# Complexity: 8.0, fitness: 1.7082937955856323, equations: [u - x0, a1*(a0*x1 + a1), a0*(a1 - 0.0227) + 0.572*tar]
# Complexity: 13.0, fitness: 0.3098561763763428, equations: [-a1 - 0.121*tar - 1.12*u + 2.38, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 4
# Complexity: 1.0, fitness: 3.986828565597534, equations: [a0, a0*a1, 0.229]
# Complexity: 2.0, fitness: 3.98376727104187, equations: [a0 + u, a1*u, a1]
# Complexity: 3.0, fitness: 2.507082939147949, equations: [a0*x1, 2*a0*a1, tar]
# Complexity: 5.0, fitness: 2.421660900115967, equations: [tar*(a1 + tar) + tar, a1 + tar, tar - 0.251]
# Complexity: 6.0, fitness: 2.29964017868042, equations: [0, a1*(tar - 0.175), a0*tar + 0.572*tar]
# Complexity: 8.0, fitness: 1.7082937955856323, equations: [u - x0, a1*(a0*x1 + a1), a0*(a1 - 0.0227) + 0.572*tar]
# Complexity: 10.0, fitness: 0.4264274835586548, equations: [u*x0*(x0 + x1), (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 13.0, fitness: 0.3098561763763428, equations: [-a1 - 0.121*tar - 1.12*u + 2.38, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 5
# Complexity: 1.0, fitness: 3.986828565597534, equations: [a0, a0*a1, 0.229]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0*x1, a1*x1, tar]
# Complexity: 4.0, fitness: 2.439091682434082, equations: [1.04*a1, tar*x1, tar - 0.144]
# Complexity: 5.0, fitness: 2.421660900115967, equations: [tar*(a1 + tar) + tar, a1 + tar, tar - 0.251]
# Complexity: 6.0, fitness: 2.29964017868042, equations: [0, a1*(tar - 0.175), a0*tar + 0.572*tar]
# Complexity: 8.0, fitness: 1.7082937955856323, equations: [u - x0, a1*(a0*x1 + a1), a0*(a1 - 0.0227) + 0.572*tar]
# Complexity: 10.0, fitness: 0.4264274835586548, equations: [u*x0*(x0 + x1), (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 13.0, fitness: 0.3098561763763428, equations: [-a1 - 0.121*tar - 1.12*u + 2.38, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 6
# Complexity: 1.0, fitness: 3.986828565597534, equations: [a0, a0*a1, 0.229]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [-0.0293*x1, a0*x1, tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 7.0, fitness: 1.667737603187561, equations: [u*x0*x1, (a1 + x1)*(a1 - tar - 0.227), a1 + tar]
# Complexity: 8.0, fitness: 0.4264274835586548, equations: [u*x0*(x0 + x1), (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 7
# Complexity: 1.0, fitness: 3.986828565597534, equations: [a0, a0*a1, 0.229]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [-0.0293*x1, a0*x1, tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 7.0, fitness: 1.667737603187561, equations: [u*x0*x1, (a1 + x1)*(a1 - tar - 0.227), a1 + tar]
# Complexity: 8.0, fitness: 0.4264274835586548, equations: [u*x0*(x0 + x1), (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 8
# Complexity: 1.0, fitness: 3.986828565597534, equations: [a0, a0*a1, 0.229]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 7.0, fitness: 1.667737603187561, equations: [u*x0*x1, (a1 + x1)*(a1 - tar - 0.227), a1 + tar]
# Complexity: 8.0, fitness: 0.4264274835586548, equations: [u*x0*(x0 + x1), (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 9
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 6.0, fitness: 1.7082937955856323, equations: [u - x0, a1*x1, a0*(a1 - 0.0227) + 0.572*tar]
# Complexity: 7.0, fitness: 0.4264274835586548, equations: [u, (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# In generation 10
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 6.0, fitness: 1.7082937955856323, equations: [u - x0, a1*x1, a0*(a1 - 0.0227) + 0.572*tar]
# Complexity: 7.0, fitness: 0.4264274835586548, equations: [u, (a1 - 0.227)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# Complexity: 18.0, fitness: 0.262918084859848, equations: [-2*a1 - 0.121*tar*u - u + 2.38, 2*a0 - tar + u + 2*x1, a0*tar + 5*a0 + tar]
# In generation 11
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 6.0, fitness: 0.31877583265304565, equations: [u*x1**2, -0.454*a1 - 0.454*x1, 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# Complexity: 12.0, fitness: 0.24190646409988403, equations: [-1.12*a1 - u + 2.38, a0 - 2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 13.0, fitness: 0.2094978541135788, equations: [-2*a1 - 0.121*u*x0 - u + 2.38, 2*a0 - tar + u + x1, 3*a0 + tar]
# In generation 12
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.39437955617904663, equations: [-x0 + x1, -0.454*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.31877583265304565, equations: [u*x1**2, -0.454*a1 - 0.454*x1, 2*a1 + tar]
# Complexity: 7.0, fitness: 0.3036839962005615, equations: [x0 + x1, (a1 - 0.454)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2727809548377991, equations: [-a1 - u + 1.88, a0 - tar + u + x1, a0*tar + 3*a0 + tar]
# Complexity: 12.0, fitness: 0.24190646409988403, equations: [-1.12*a1 - u + 2.38, a0 - 2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 13.0, fitness: 0.2094978541135788, equations: [-2*a1 - 0.121*u*x0 - u + 2.38, 2*a0 - tar + u + x1, 3*a0 + tar]
# In generation 13
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.39437955617904663, equations: [-x0 + x1, -0.454*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.31877583265304565, equations: [u*x1**2, -0.454*a1 - 0.454*x1, 2*a1 + tar]
# Complexity: 7.0, fitness: 0.3036839962005615, equations: [x0 + x1, (a1 - 0.454)*(a1 + x1), 2*a1 + tar]
# Complexity: 9.0, fitness: 0.29946210980415344, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 2*a0 + tar]
# Complexity: 10.0, fitness: 0.2780832350254059, equations: [-1.12*a1 - u + 2.38, a0 - tar + u + x1, 3*a0 + tar]
# Complexity: 11.0, fitness: 0.2444385290145874, equations: [-1.12*a1 - u + 2.38, -2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 12.0, fitness: 0.24190646409988403, equations: [-1.12*a1 - u + 2.38, a0 - 2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 13.0, fitness: 0.2094978541135788, equations: [-2*a1 - 0.121*u*x0 - u + 2.38, 2*a0 - tar + u + x1, 3*a0 + tar]
# In generation 14
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.39437955617904663, equations: [-x0 + x1, -0.454*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.31877583265304565, equations: [u*x1**2, -0.454*a1 - 0.454*x1, 2*a1 + tar]
# Complexity: 7.0, fitness: 0.3036839962005615, equations: [x0 + x1, (a1 - 0.454)*(a1 + x1), 2*a1 + tar]
# Complexity: 8.0, fitness: 0.2946886420249939, equations: [-a1 - u + 1.88, -2*tar + 2*u + x1, 2*a0]
# Complexity: 9.0, fitness: 0.2606797516345978, equations: [-a1 - u + 2.38, -2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 11.0, fitness: 0.2444385290145874, equations: [-1.12*a1 - u + 2.38, -2*tar + 2*u + x1, 2*a0 + tar + 0.103]
# Complexity: 12.0, fitness: 0.22375789284706116, equations: [-3*a1 - 2*u + 4.75, a0 - tar + u + x1, 2*a0 + tar + 0.103]
# Complexity: 13.0, fitness: 0.2094978541135788, equations: [-2*a1 - 0.121*u*x0 - u + 2.38, 2*a0 - tar + u + x1, 3*a0 + tar]
# In generation 15
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.39437955617904663, equations: [-x0 + x1, -0.454*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.31877583265304565, equations: [u*x1**2, -0.454*a1 - 0.454*x1, 2*a1 + tar]
# Complexity: 7.0, fitness: 0.2640388607978821, equations: [2*x0, -0.908*a1 - 0.454*x1 + 0.103, 2*a1 + tar]
# Complexity: 9.0, fitness: 0.24918486177921295, equations: [-a1 - u + 2.38, -2*tar + 2*u + x1, 3*a0 + tar]
# Complexity: 10.0, fitness: 0.21175846457481384, equations: [-2*a1 - u + 1.88, a0 - tar + u + x1, 2*a0 + tar + 0.103]
# Complexity: 11.0, fitness: 0.20714880526065826, equations: [u*x0*(u*x0*x1 + x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 2*a1 + tar]
# In generation 16
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.3007732033729553, equations: [u, -0.908*a1 - 0.454*x1, a1 + tar]
# Complexity: 7.0, fitness: 0.2640388607978821, equations: [2*x0, -0.908*a1 - 0.454*x1 + 0.103, 2*a1 + tar]
# Complexity: 8.0, fitness: 0.19831717014312744, equations: [tar*x0*(tar + u - x0) - x0, -1.34*a1 - 1.34*x1, a1 + tar]
# In generation 17
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.507082939147949, equations: [x0, a1*x1, -a1 + tar]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.3007732033729553, equations: [u, -0.908*a1 - 0.454*x1, a1 + tar]
# Complexity: 7.0, fitness: 0.2640388607978821, equations: [2*x0, -0.908*a1 - 0.454*x1 + 0.103, 2*a1 + tar]
# Complexity: 8.0, fitness: 0.19831717014312744, equations: [tar*x0*(tar + u - x0) - x0, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 11.0, fitness: 0.19324269890785217, equations: [tar*x0*(tar + u*x0*x1) - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 14.0, fitness: 0.1911517232656479, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# In generation 18
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.3007732033729553, equations: [u, -0.908*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.20714880526065826, equations: [u, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 2*a1 + tar]
# Complexity: 8.0, fitness: 0.19831717014312744, equations: [tar*x0*(tar + u - x0) - x0, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 11.0, fitness: 0.19324269890785217, equations: [tar*x0*(tar + u*x0*x1) - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 14.0, fitness: 0.1911517232656479, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# In generation 19
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.3007732033729553, equations: [u, -0.908*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.20714880526065826, equations: [u, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 2*a1 + tar]
# Complexity: 8.0, fitness: 0.19831717014312744, equations: [tar*x0*(tar + u - x0) - x0, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 11.0, fitness: 0.19324269890785217, equations: [tar*x0*(tar + u*x0*x1) - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 14.0, fitness: 0.1911517232656479, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# In generation 20
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.3007732033729553, equations: [u, -0.908*a1 - 0.454*x1, a1 + tar]
# Complexity: 6.0, fitness: 0.20714880526065826, equations: [u, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 2*a1 + tar]
# Complexity: 8.0, fitness: 0.19831717014312744, equations: [tar*x0*(tar + u - x0) - x0, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.19324269890785217, equations: [2*tar**2*x0 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 14.0, fitness: 0.1911517232656479, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# Complexity: 16.0, fitness: 0.18917112052440643, equations: [2*u**2*x0**2*x1, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar]
# In generation 21
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [0, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 14.0, fitness: 0.1911517232656479, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# Complexity: 15.0, fitness: 0.190668523311615, equations: [tar*x0*(tar + u*x0*x1) - x0, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18771733343601227, equations: [u*x0*(u*x0**2 + u*x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# In generation 22
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18771733343601227, equations: [u*x0*(u*x0**2 + u*x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# In generation 23
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18771733343601227, equations: [u*x0*(u*x0**2 + u*x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# In generation 24
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18760931491851807, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.106]
# Complexity: 17.0, fitness: 0.1875317245721817, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# In generation 25
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 14.0, fitness: 0.1878429353237152, equations: [x0 + (x1 - 0.949)*(x0*x1 + x0), -0.454*a1 + 0.908*tar - 0.908*u - 0.908*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18760931491851807, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.106]
# Complexity: 17.0, fitness: 0.1875317245721817, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 18.0, fitness: 0.18746548891067505, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar]
# In generation 26
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 14.0, fitness: 0.1878429353237152, equations: [x0 + (x1 - 0.949)*(x0*x1 + x0), -0.454*a1 + 0.908*tar - 0.908*u - 0.908*x1, 2*a1 + tar]
# Complexity: 16.0, fitness: 0.18760931491851807, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.106]
# Complexity: 17.0, fitness: 0.1875317245721817, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 18.0, fitness: 0.18746548891067505, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar]
# In generation 27
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [x0*(u + x0), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 16.0, fitness: 0.18760931491851807, equations: [2*u**2*x0**2*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.106]
# Complexity: 17.0, fitness: 0.1875317245721817, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 18.0, fitness: 0.18746548891067505, equations: [a1*u*(u**2*x1 + u*(-x0 + x1)), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar]
# In generation 28
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.190668523311615, equations: [-x0 + x1, -4.03*a1 + 1.34*tar - 1.34*u - 2.69*x1, 2*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [x0*(u + x0), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 16.0, fitness: 0.1873553842306137, equations: [x0*(u**2*x0 + x0*x1 + x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 29
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.1878429353237152, equations: [u*x0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [u*x0**2, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873553842306137, equations: [x0*(u + x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 30
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.18771733343601227, equations: [u*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [u*x0**2, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873553842306137, equations: [x0*(u + x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 31
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.18771733343601227, equations: [a0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [u*x0**2, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873553842306137, equations: [x0*(u + x0*x1), -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 32
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.18771733343601227, equations: [a0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 11.0, fitness: 0.18761804699897766, equations: [u*x0**2, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 12.0, fitness: 0.1873553842306137, equations: [2*u*x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 33
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.18771733343601227, equations: [a0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 11.0, fitness: 0.1873553842306137, equations: [x0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 34
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 35
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# In generation 36
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 19.0, fitness: 0.1873464733362198, equations: [2*a1*u**2*(-x0 + x1), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 37
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.1911517232656479, equations: [0.885*x0*x1, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 19.0, fitness: 0.1873464733362198, equations: [2*a1*u**2*(-x0 + x1), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 38
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.1911517232656479, equations: [x0*x1 + 0.885, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 14.0, fitness: 0.18734648823738098, equations: [u**2*x0, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 17.0, fitness: 0.1873464733362198, equations: [a1*u*(u*(-x0 + x1) + u), -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 39
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.1911517232656479, equations: [x0*x1 + 0.885, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 3*a1 + tar]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 14.0, fitness: 0.18734648823738098, equations: [a1*u*x0, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 16.0, fitness: 0.1873464733362198, equations: [a1**2*u + u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 40
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [tar, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 14.0, fitness: 0.18734648823738098, equations: [a1*u*x0, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 15.0, fitness: 0.1873464733362198, equations: [a1**2*u + u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 41
# Complexity: 1.0, fitness: 3.98376727104187, equations: [a1, a1*x1, a0]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [u, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 42
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 43
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 44
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 45
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19324269890785217, equations: [2*tar**2 - x0, -2.69*a1 - 2.69*x1, a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 46
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 47
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 48
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 49
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 11.0, fitness: 0.18735504150390625, equations: [u + x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.103]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# In generation 50
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 11.0, fitness: 0.18735504150390625, equations: [u + x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.103]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Final pareto front:
# Complexity: 1.0, fitness: 3.98376727104187, equations: [u + x0, a1, a1]
# Complexity: 2.0, fitness: 2.493032932281494, equations: [u, a1, a1 + tar - 0.0227]
# Complexity: 3.0, fitness: 2.2944700717926025, equations: [u - x0, tar, 0.572*tar - 0.0227]
# Complexity: 4.0, fitness: 0.19831717014312744, equations: [x0*x1, -1.34*a1 - 1.34*x1, a1 + tar]
# Complexity: 8.0, fitness: 0.19285303354263306, equations: [a1, 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar]
# Complexity: 9.0, fitness: 0.18761804699897766, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 4*a1 + tar + 0.109]
# Complexity: 10.0, fitness: 0.1873553842306137, equations: [x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.109]
# Complexity: 11.0, fitness: 0.18735504150390625, equations: [u + x0, -0.454*a1 + 0.454*tar - 0.454*u - 0.454*x1, 5*a1 + tar + 0.103]
# Complexity: 12.0, fitness: 0.18734648823738098, equations: [u, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]
# Complexity: 13.0, fitness: 0.1873464733362198, equations: [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]

# %% [markdown]
# ## Visualize best solution

# %%
#Generate test_data
data = get_data(jr.PRNGKey(10), env, 4, 0.01, T, param_setting)
x0s, ts, targets, noise_key, params = data

pareto_fitness, pareto_front = strategy.pareto_front
best_candidate = pareto_front[jnp.argmin(pareto_fitness)]
print(strategy.expression_to_string(best_candidate))

xs, ys, us, activities, fitness = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[None, 0, None, 0, 0, 0, None])(best_candidate, *data, strategy.tree_evaluator)

fig, ax = plt.subplots(2, 2, figsize=(10, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, xs[i,:,0], label="$x_0$", color = "blue")
    ax[i].plot(ts, xs[i,:,1], label="$x_1$", color = "orange")
    ax[i].plot(ts, ys[i,:,0], alpha=0.3, color = "blue")
    ax[i].plot(ts, ys[i,:,1], alpha=0.3, color = "orange")
    ax[i].plot(ts, us[i,:], label="$u$", color = "green")
    ax[i].hlines(targets[i], ts[0], ts[-1], linestyles='dashed', color = "black")

plt.suptitle("Trajectories of the stochastic harmonic oscillator controlled with a symbolic policy")
plt.legend(loc="best")
plt.show()
# Out:
# [u**2, -0.908*a1 + 0.454*tar - 0.454*u - 0.454*x1, 6*a1 + tar + 0.0316]

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, activities[i,:,0], label="$a_0$", color = "red")
    ax[i].plot(ts, activities[i,:,1], label="$a_1$", color = "purple")

plt.suptitle("Latent activity of the memory of the policy")
plt.legend(loc="best")
plt.show()
